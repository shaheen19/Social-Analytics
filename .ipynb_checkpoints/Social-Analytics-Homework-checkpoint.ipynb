# %% [markdown]
# # Analysis

# %% [markdown]
# ##### Observed trend 1: On November 5, 2017, overall sentiment polarity is positive for BBC and CBS tweets and negative for Fox News and CNN. For NY Times, the tweet sentiment is almost neutral.

# %% [markdown]
# ##### Observed trend 2: From the overall media sentiment based on tweets, CBS is most positive at 23% and BBC is the second most positive with 7.7%.

# %% [markdown]
# ##### Observed trend 3: The results also show that CNN is most negative with 14.9 % negative polarity and Fox News is second with 13%.NY Times has 3.1% negative polarity, which the closest to neutral.

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import tweepy
import time
from datetime import datetime
from config1 import consumer_key, consumer_secret, access_token, access_token_secret
# Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
consumer_key = "Ed4RNulN1lp7AbOooHa9STCoU"
consumer_secret = "P7cUJlmJZq0VaCY0Jg7COliwQqzK0qYEyUF9Y0idx4ujb3ZlW5"
access_token = "839621358724198402-dzdOsx2WWHrSuBwyNUiqSEnTivHozAZ"
access_token_secret = "dCZ80uNRbFDjxdU2EckmNiSckdoATach6Q8zb7YYYE5ER"

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %% [markdown]
# # Get sentiments data from Media Tweets and creat dataframe

# %%
# Target Search Term
target_terms = ("BBC", "CBS", "CNN",
                "FoxNews", "nytimes")

# %%
# Array to hold sentiment
sentiments_all = []
# Counter
counter = 1

# %%
# Loop through all target users
for target in target_terms:

    # Variables for holding sentiments
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []
    for x in range(5):

        # Get all tweets from home feed
        public_tweets = api.user_timeline(target, page=x)
        # Loop through all tweets 
        for tweet in public_tweets:
        
            # Run Vader Analysis on each tweet
            compound = analyzer.polarity_scores(tweet["text"])["compound"]
            pos = analyzer.polarity_scores(tweet["text"])["pos"]
            neu = analyzer.polarity_scores(tweet["text"])["neu"]
            neg = analyzer.polarity_scores(tweet["text"])["neg"]
            tweets_ago = counter
            
            compound_list.append(compound)
            positive_list.append(pos)
            negative_list.append(neg)
            neutral_list.append(neu)


            # Add sentiments for each tweet into an array
            sentiments_all.append({"User": target, 
                           "Source account": tweet["source"],
                           "Date": tweet["created_at"],        
                           "Text": tweet["text"],
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
            
            
            # Add to counter 
            counter = counter + 1
    
    

print(sentiments_all)
print("")
# Out:
# [{'User': 'BBC', 'Source account': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'Date': 'Sun Aug 26 19:39:07 +0000 2018', 'Text': 'RT @BBCOne: 🚨 Consider this your 30-minute warning! 🚨\n#Bodyguard. Starts tonight at 9pm, @BBCOne. https://t.co/m8JzlprYRG', 'Compound': -0.4003, 'Positive': 0.0, 'Negative': 0.828, 'Neutral': 0.172, 'Tweets Ago': 1}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Sun Aug 26 19:13:06 +0000 2018', 'Text': 'A troubled war veteran is assigned to protect a controversial politician...\n\n#Bodyguard | 9pm | @BBCOne |… https://t.co/SopVXMpTWg', 'Compound': -0.7269, 'Positive': 0.122, 'Negative': 0.469, 'Neutral': 0.408, 'Tweets Ago': 2}, {'User': 'BBC', 'Source account': '<a href="https://studio.twitter.com" rel="nofollow">Media Studio</a>', 'Date': 'Sun Aug 26 18:05:00 +0000 2018', 'Text': '🕵️😂 Did you know Sherlock is Indian? \n#GoodnessGraciousMe https://t.co/quFCCTvECl', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 3}, {'User': 'BBC', 'Source account': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'Date': 'Sun Aug 26 16:46:09 +0000 2018', 'Text': "The perfect picnic doesn't exi- \n#NationalDogDay https://t.co/hCE7MqzF2P", 'Compound': 0.5719, 'Positive': 0.381, 'Negative': 0.619, 'Neutral': 0.0, 'Tweets Ago': 4}, {'User': 'BBC', 'Source account': '<a href="https://studio.twitter.com" rel="nofollow">Media Studio</a>', 'Date': 'Sun Aug 26 16:32:00 +0000 2018', 'Text': 'This sketch was discovered in Germany, but could it be by British artist Henry Moore? Fiona Bruce and @PhilipMould… https://t.co/gGf2OFwsVI', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 5}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Sun Aug 26 15:05:02 +0000 2018', 'Text': '😴 It’s hard to overstate the benefits of a night’s rest for human memory, and neuroscientists are just beginning to… https://t.co/GK81wfxhJ3', 'Compound': 0.296, 'Positive': 0.124, 'Negative': 0.81, 'Neutral': 0.067, 'Tweets Ago': 6}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Sun Aug 26
# 483  In Opinion\n\nOp-Ed contributor Naka Nathaniel...         484  nytimes
# 484  RT @nytpolitics: Reporters and editors at The ...         485  nytimes
# 485  Finland, Norway, Denmark, Iceland and Sweden r...         486  nytimes
# 486  The median survival term for glioblastoma, whi...         487  nytimes
# 487  Republican ads show scenes of a violent, anarc...         488  nytimes
# 488  Breaking News: An archbishop claimed that Pope...         489  nytimes
# 489  RT @nytimesworld: Follow our live updates as t...         490  nytimes
# 490  “Being among old growth trees feels as sacred ...         491  nytimes
# 491  In his decision to keep Tesla public, Elon Mus...         492  nytimes
# 492  In @NYTOpinion, \nOp-Ed contributor Anand Giri...         493  nytimes
# 493  John McCain will be the 13th former senator to...         494  nytimes
# 494  A Single Road With Many Names, Traversing Many...         495  nytimes
# 495  RT @nytopinion: "We are a country with a consc...         496  nytimes
# 496  Police in Turkey Break Up Mothers’ Weekly Vigi...         497  nytimes
# 497  A new psychological approach targets anxiety, ...         498  nytimes
# 498  "The Happytime Murders" and "Puppet Master: Th...         499  nytimes
# 499  During a recent operation to repair a metal ro...         500  nytimes
#
# [500 rows x 9 columns]

# %%
sentiments_pd= sentiments_pd.set_index("User")
sentiments_pd.head()
# Out:
#       Compound                            Date  Negative  Neutral  Positive  \
# User
# BBC    -0.4003  Sun Aug 26 19:39:07 +0000 2018     0.828    0.172     0.000
# BBC    -0.7269  Sun Aug 26 19:13:06 +0000 2018     0.469    0.408     0.122
# BBC     0.0000  Sun Aug 26 18:05:00 +0000 2018     1.000    0.000     0.000
# BBC     0.5719  Sun Aug 26 16:46:09 +0000 2018     0.619    0.000     0.381
# BBC     0.0000  Sun Aug 26 16:32:00 +0000 2018     1.000    0.000     0.000
#
#                                          Source account  \
# User
# BBC   <a href="http://twitter.com/download/iphone" r...
# BBC   <a href="http://www.socialflow.com" rel="nofol...
# BBC   <a href="https://studio.twitter.com" rel="nofo...
# BBC   <a href="http://twitter.com" rel="nofollow">Tw...
# BBC   <a href="https://studio.twitter.com" rel="nofo...
#
#                                                    Text  Tweets Ago
# User
# BBC   RT @BBCOne: 🚨 Consider this your 30-minute war...           1
# BBC   A troubled war veteran is assigned to protect ...           2
# BBC   🕵️😂 Did you know Sherlock is Indian? \n#Goodne...           3
# BBC   The perfect picnic doesn't exi- \n#NationalDog...           4
# BBC   This sketch was discovered in Germany, but cou...           5

# %% [markdown]
# # Save the DataFrame as a csv

# %%
#sentiments_pd.to_csv("../Instructions/media_sentiments_analysis.csv", encoding="utf-8", index=False)

# %% [markdown]
# # Sentiment Analysis of Media Tweets

# %%
BBC_compound = sentiments_pd.loc["BBC", "Compound"]
CBS_compound = sentiments_pd.loc["CBS", "Compound"] 
CNN_compound = sentiments_pd.loc["CNN", "Compound"] 
Fox_compound = sentiments_pd.loc["FoxNews", "Compound"] 
nytimes_compound = sentiments_pd.loc["nytimes", "Compound"] 
BBC_compound =BBC_compound.reset_index()
CBS_compound =CBS_compound.reset_index()
CNN_compound =CNN_compound.reset_index()
Fox_compound =Fox_compound.reset_index()
nytimes_compound =nytimes_compound.reset_index()

# %%
Compound_df=pd.concat([BBC_compound, CBS_compound, CNN_compound, Fox_compound,nytimes_compound],axis=1)
Compound_df
Compound_df.columns.values[1] = 'BBC Compound' 
Compound_df.columns.values[3] = 'CBS Compound'
Compound_df.columns.values[5] = 'CNN Compound'
Compound_df.columns.values[7] = 'FoxNews Compound'
Compound_df.columns.values[9] = 'NYtimes Compound'
Compound_df.head()
# Out:
#   User  BBC Compound User  CBS Compound User  CNN Compound     User  \
# 0  BBC       -0.4003  CBS       -0.4389  CNN       -0.6486  FoxNews
# 1  BBC       -0.7269  CBS        0.0000  CNN        0.0000  FoxNews
# 2  BBC        0.0000  CBS        0.0000  CNN        0.0000  FoxNews
# 3  BBC        0.5719  CBS        0.5423  CNN        0.4019  FoxNews
# 4  BBC        0.0000  CBS        0.3182  CNN       -0.7964  FoxNews
#
#    FoxNews Compound     User  NYtimes Compound
# 0            0.8176  nytimes            0.4215
# 1            0.8555  nytimes           -0.4019
# 2            0.0000  nytimes            0.8126
# 3            0.8360  nytimes            0.0000
# 4            0.0000  nytimes           -0.4767

# %% [markdown]
# # Create plot

# %%
mpl_fig = plt.figure()
ax = mpl_fig.add_subplot(111)
ax.set_facecolor('lavender')
BBC = ax.scatter(np.arange(len(Compound_df["BBC Compound"])),
         Compound_df["BBC Compound"], marker="o", color="red", edgecolors="k",
         alpha=0.8, s=80 ) 
CBS = ax.scatter(np.arange(len(Compound_df["BBC Compound"])),
         Compound_df["CBS Compound"], marker="o", color="blue", edgecolors="k",
         alpha=0.8,s=80)
CNN = ax.scatter(np.arange(len(Compound_df["BBC Compound"])),
         Compound_df["CNN Compound"], marker="o", color="yellow", edgecolors="k",
         alpha=0.8 ,s=80)
Fox = ax.scatter(np.arange(len(Compound_df["BBC Compound"])),
         Compound_df["FoxNews Compound"], marker="o", color="green", edgecolors="k",
         alpha=0.8,s=80)
nytimes = ax.scatter(np.arange(len(Compound_df["BBC Compound"])),
         Compound_df["NYtimes Compound"], marker="o", color="black", edgecolors="k",
         alpha=0.8,s=80)
# # Incorporate the other graph properties

plt.title("Sentiment Analysis of Media Tweets (11/5/17)")
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.grid(True, linestyle='dashed')
plt.legend((BBC, CBS, CNN, Fox, nytimes), ("BBC Compound","CBS Compound","CNN Compound","FoxNews Compound","NYtimes Compound"),
           loc='lower left',
           bbox_to_anchor=(1, 0.6))
plt.savefig("Sentiment_Analysis_of_Media_Tweets_11_5_2017")     
plt.show()

# %%
average_BBC = Compound_df["BBC Compound"].mean()
average_CBS = Compound_df["CBS Compound"].mean()
average_CNN = Compound_df["CNN Compound"].mean()
average_Fox = Compound_df["FoxNews Compound"].mean()
average_nytimes = Compound_df["NYtimes Compound"].mean()

averages = {'Compound': pd.Series([average_BBC,average_CBS,average_CNN, average_Fox, average_nytimes],index=['BBC','CBS','CNN','FoxNews','NYtimes'] )}
Compound_mean_df = pd.DataFrame(averages)
Compound_mean_df=Compound_mean_df.reset_index()
Compound_mean_df
# Out:
#      index  Compound
# 0      BBC  0.078293
# 1      CBS  0.188929
# 2      CNN -0.039909
# 3  FoxNews -0.023577
# 4  NYtimes  0.024888

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
x_axis = np.arange(0, len(Compound_mean_df["index"]))
tick_locations = []
for x in x_axis:
    tick_locations.append(x + 0.4)
ax.bar(x_axis, Compound_mean_df["Compound"], alpha=0.75, color="rbygk", align="edge")    

ax.set_ylabel('Tweet Polarity')
ax.set_title("Overrall Media Sentiment based on Twitter (11/5/2017)")
ax.set_facecolor('lavender')
plt.xticks(tick_locations, Compound_mean_df["index"])
plt.axhline(0, color='k')
plt.savefig("Overrall_Media_Sentiment_based_on_Twitter_11_5_2017")
plt.show()
