# %% [markdown]
# # Analysis

# %% [markdown]
# ### VADER Sentiment Lexicon
# ## -1 = slighlty negative, -2 = moderately negative,  -3= very negative, -4 = extremely negative.
# ## 0 = neutral
# ## +1 = slighlty positive, + 2 = moderately positive,  +3= very positive, + 4 = extremely positive.

# %% [markdown]
#  ### Observed Trend 1: On August 28, 2018 overall sentiment polarity is positive for BBC and CBS including Fox News and NewYork Times.
#  ### Observed Trend 2:  Only CNN showed negative polarity compared to the other four media outlet tweets.
#  ### Observed Trend 3: Based on the maximum positive (+4) and maximum negative (-4) limits sets by Vader analysis CBS is moderately positve at ~ 19%  followed by BBC ~14%. Fox news and New YOrk Times are slighlty positive ~0.2%.
#  ### Observed Trend 4: Based on the minimum positive (+1) and min negative (-1) limits sets by Vader analysis, CNN is slightly negative at ~ -0.2%.

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import tweepy
import time
from datetime import datetime
from config import consumer_key, consumer_secret, access_token, access_token_secret
# Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()



# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %% [markdown]
# # Get sentiments data from Media Tweets and creat dataframe

# %%
# Target Search Term
target_terms = ("BBC", "CBS", "CNN",
                "FoxNews", "nytimes")

# %%
# Array to hold sentiment
sentiments_all = []
# Counter
counter = 1

# %%
# Loop through all target users
for target in target_terms:

    # Variables for holding sentiments
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []
    for x in range(5):

        # Get all tweets from home feed
        public_tweets = api.user_timeline(target, page=x)
        # Loop through all tweets 
        for tweet in public_tweets:
        
            # Run Vader Analysis on each tweet
            compound = analyzer.polarity_scores(tweet["text"])["compound"]
            pos = analyzer.polarity_scores(tweet["text"])["pos"]
            neu = analyzer.polarity_scores(tweet["text"])["neu"]
            neg = analyzer.polarity_scores(tweet["text"])["neg"]
            tweets_ago = counter
            
            compound_list.append(compound)
            positive_list.append(pos)
            negative_list.append(neg)
            neutral_list.append(neu)


            # Add sentiments for each tweet into an array
            sentiments_all.append({"User": target, 
                           "Source account": tweet["source"],
                           "Date": tweet["created_at"],        
                           "Text": tweet["text"],
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
            
            
            # Add to counter 
            counter = counter + 1
    
    

print(sentiments_all)
print("")
# Out:
# [{'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Tue Aug 28 18:56:05 +0000 2018', 'Text': '🐢 Scientists have found new evidence confirming that turtles once lived without shells.\n👉 https://t.co/xLIFJNJdh1 https://t.co/VUcP8zguW7', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 1}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Tue Aug 28 18:03:04 +0000 2018', 'Text': 'A conversation with a homeless man inspired Stephen to attempt the unusual challenge of crossing the Alps on a spac… https://t.co/w6h0Yhe5bf', 'Compound': 0.5423, 'Positive': 0.22, 'Negative': 0.78, 'Neutral': 0.0, 'Tweets Ago': 2}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Tue Aug 28 16:01:02 +0000 2018', 'Text': "😂 If Britney's songs were Scottish. https://t.co/Em0LRQmbFt", 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 3}, {'User': 'BBC', 'Source account': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'Date': 'Tue Aug 28 14:51:38 +0000 2018', 'Text': 'RT @BBCOne: Be careful who you trust.\n\n#Bodyguard. Continues Sundays at 9pm on @BBCOne. Or available to watch on @BBCiPlayer: https://t.co/…', 'Compound': 0.5994, 'Positive': 0.205, 'Negative': 0.795, 'Neutral': 0.0, 'Tweets Ago': 4}, {'User': 'BBC', 'Source account': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'Date': 'Tue Aug 28 14:51:32 +0000 2018', 'Text': 'RT @BBCiPlayer: Watch the highlights from Reading and Leeds Festivals on BBC iPlayer 🙌 \nhttps://t.co/AfQl9nXavO https://t.co/KGbRUouFCZ', 'Compound': 0.3612, 'Positive': 0.152, 'Negative': 0.848, 'Neutral': 0.0, 'Tweets Ago': 5}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Tue Aug 28 13:02:04 +0000 2018', 'Text': 'Once upon a time, two early humans of different ancestry met at a cave in Russia.\n\n50,000 years later, scientists h… https://t.co/oOCBlGLFqQ', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 6}, {'User': 'BBC', 'Source account': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'Date': 'Tue Aug 28 12:48:59 +0000 2018', 'Text': '@BBCTravelShow is on @BBCiPlayer now 👉 https://t.co/Sqn5y0xC80', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 7}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Tue Aug 28 12:00:18 +0000 2018', 'Text': '🍅 Neighbourhood gardens are providing important access to fresh food in urban areas. https://t.co/wLol6vY5rW', 'Compound': 0.4767, 'Positive': 0.272, 'Negative': 0.728, 'Neutral': 0.0, 'Tweets Ago': 8}, {'User': 'BBC', 'Source account': '<a href="https://studio.twitter.com" rel="nofollow">Media Studio</a>', 'Date': 'Tue Aug 28 11:33:00 +0000 2018', 'Text': 'This sweet, sticky rice is hit 100 times with a mallet to create a delicious Japanese dessert. 🍚🔨 #TheTravelShow https://t.co/jLazGPrVH1', 'Compound': 0.8316, 'Positive': 0.37, 'Negative': 0.63, 'Neutral': 0.0, 'Tweets Ago': 9}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Tue Aug 28 11:01:01 +0000 2018', 'Text': '🍯 Honey and over-the-counter meds should be the first line of treatment for most people with coughs to avoid antibi… https://t.co/di9e7UgCm9', 'Compound': -0.296, 'Positive': 0.0, 'Negative': 0.896, 'Neutral': 0.104, 'Tweets Ago': 10}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Tue Aug 28 08:00:16 +0000 2018', 'Text': '❤️🐾 So many puppies and kittens will be safer because of this.\n#LucysLaw https://t.co/LyF6u8hy2n', 'Compound': 0.4215, 'Positive': 0.177, 'Neg ...

# %%
# Convert sentiments to DataFrame
sentiments_pd = pd.DataFrame.from_dict(sentiments_all)
sentiments_pd
# Out:
#      Compound                            Date  Negative  Neutral  Positive  \
# 0      0.0000  Tue Aug 28 18:56:05 +0000 2018     1.000    0.000     0.000
# 1      0.5423  Tue Aug 28 18:03:04 +0000 2018     0.780    0.000     0.220
# 2      0.0000  Tue Aug 28 16:01:02 +0000 2018     1.000    0.000     0.000
# 3      0.5994  Tue Aug 28 14:51:38 +0000 2018     0.795    0.000     0.205
# 4      0.3612  Tue Aug 28 14:51:32 +0000 2018     0.848    0.000     0.152
# 5      0.0000  Tue Aug 28 13:02:04 +0000 2018     1.000    0.000     0.000
# 6      0.0000  Tue Aug 28 12:48:59 +0000 2018     1.000    0.000     0.000
# 7      0.4767  Tue Aug 28 12:00:18 +0000 2018     0.728    0.000     0.272
# 8      0.8316  Tue Aug 28 11:33:00 +0000 2018     0.630    0.000     0.370
# 9     -0.2960  Tue Aug 28 11:01:01 +0000 2018     0.896    0.104     0.000
# 10     0.4215  Tue Aug 28 08:00:16 +0000 2018     0.823    0.000     0.177
# 11     0.0000  Tue Aug 28 07:26:06 +0000 2018     1.000    0.000     0.000
# 12     0.1280  Tue Aug 28 07:00:13 +0000 2018     0.821    0.077     0.103
# 13     0.6240  Mon Aug 27 20:01:03 +0000 2018     0.806    0.000     0.194
# 14     0.0772  Mon Aug 27 19:36:00 +0000 2018     0.936    0.000     0.064
# 15     0.5859  Mon Aug 27 19:03:04 +0000 2018     0.752    0.062     0.186
# 16    -0.4939  Mon Aug 27 18:12:05 +0000 2018     0.862    0.138     0.000
# 17     0.0000  Mon Aug 27 17:05:04 +0000 2018     1.000    0.000     0.000
# 18     0.0772  Mon Aug 27 16:03:04 +0000 2018     0.944    0.000     0.056
# 19     0.0000  Mon Aug 27 14:08:03 +0000 2018     1.000    0.000     0.000
# 20     0.0000  Tue Aug 28 18:56:05 +0000 2018     1.000    0.000     0.000
# 493  <a href="http://www.socialflow.com" rel="nofol...
# 494  <a href="http://www.socialflow.com" rel="nofol...
# 495  <a href="http://www.socialflow.com" rel="nofol...
# 496  <a href="http://www.socialflow.com" rel="nofol...
# 497  <a href="http://www.socialflow.com" rel="nofol...
# 498  <a href="http://www.socialflow.com" rel="nofol...
# 499  <a href="http://www.socialflow.com" rel="nofol...
#
#                                                   Text  Tweets Ago     User
# 0    🐢 Scientists have found new evidence confirmin...           1      BBC
# 1    A conversation with a homeless man inspired St...           2      BBC
# 2    😂 If Britney's songs were Scottish. https://t....           3      BBC
# 3    RT @BBCOne: Be careful who you trust.\n\n#Body...           4      BBC
# 4    RT @BBCiPlayer: Watch the highlights from Read...           5      BBC
# 5    Once upon a time, two early humans of differen...           6      BBC
# 6    @BBCTravelShow is on @BBCiPlayer now 👉 https:/...           7      BBC
# 7    🍅 Neighbourhood gardens are providing importan...           8      BBC
# 8    This sweet, sticky rice is hit 100 times with ...           9      BBC
# 9    🍯 Honey and over-the-counter meds should be th...          10      BBC
# 10   ❤️🐾 So many puppies and kittens will be safer ...          11      BBC
# 11   What's the real price of getting rid of plasti...          12      BBC
# 12   😲 Researchers have created a virtual reality s...          13      BBC
# 13   Nikki Bedi interviews one of Britain's most su...          14      BBC
# 14   🙈 Walking in on your mum. The last thing you w...          15      BBC
# 15   In this revealingly intimate documentary, Adri...          16      BBC
# 16   More than half of Borneo's orangutans have per...          17      BBC
# 17   🎻 The incredible orchestra with a difference. ...          18      BBC
# 18   An increasing number of South Korean women are...          19      BBC
# 19   😂🐋🚌 'Before there were London buses, what did ...          20      BBC
# 20   🐢 Scientists have found new evidence confirmin...          21      BBC
# 21   A conversation with a homeless man inspired St...          22      BBC
# 22   😂 If Britney's songs were Scottish. https://t....          23      BBC
# 23   RT @BBCOne: Be careful who you trust.\n\n#Body...          24      BBC
# 24   RT @BBCiPlayer: Watch the highlights from Read...          25      BBC
# 25   Once upon a time, two early humans of differen...          26      BBC
# 26   @BBCTravelShow is on @BBCiPlayer now 👉 https:/...          27      BBC
# 27   🍅 Neighbourhood gardens are providing importan...          28      BBC
# 28   This sweet, sticky rice is hit 100 times with ...          29      BBC
# 29   🍯 Honey and over-the-counter meds should be th...          30      BBC
# ..                                                 ...         ...      ...
# 470  RT @juliehdavis: "You’re one election away fro...         471  nytimes
# 471  In remarks to evangelical ministers, President...         472  nytimes
# 472  Correction: A previous version of this tweet i...         473  nytimes
# 473  A books dealer and a library archivist have be...         474  nytimes
# 474  RT @TimHerrera: We're all afraid to talk about...         475  nytimes
# 475  France's environment minister resigned during ...         476  nytimes
# 476  “As a Democrat in Arizona, I voted for McCain ...         477  nytimes
# 477  52 Places Traveler: A pilgrimage to Ypres, a s...         478  nytimes
# 478  Nearly 3,000 more deaths than expected occurre...         479  nytimes
# 479  RT @thunderwooddd: Today's the day! More than ...         480  nytimes
# 480  Over the years, Ethan Hawke somehow worn his c...         481  nytimes
# 481  RT @NYTmag: Bees love protein patties. https:/...         482  nytimes
# 482  “The reason Elon seems to attract drama is tha...         483  nytimes
# 483  From cocktail hideways to a taste of West Afri...         484  nytimes
# 484  RT @tmagazine: How the common weed has grown o...         485  nytimes
# 485  "We were two journalists with four cameras, a ...         486  nytimes
# 486  Canada's foreign minister rushed to Washington...         487  nytimes
# 487  Oklahoma primary runoff election results. Foll...         488  nytimes
# 488  Arizona primary election results. Follow along...         489  nytimes
# 489  Florida primary election results. Follow along...         490  nytimes
# 490  RT @adeelnyt: Emmett Till, 14, entered a white...         491  nytimes
# 491  The president of the French Tennis Federation ...         492  nytimes
# 492  RT @ShaneGoldmacher: Some context on this: Cuo...         493  nytimes
# 493  Our Moscow correspondent examines how the Krem...         494  nytimes
# 494  In Opinion\n\nJack Shenker writes, "Since the ...         495  nytimes
# 495  RT @nytimesarts: Earlier this year, Abby Schac...         496  nytimes
# 496  RT @NYTmag: "Serena’s excellence comes with th...         497  nytimes
# 497  You know that study that said no amount of alc...         498  nytimes
# 498  Andrew Cuomo and Cynthia Nixon are set to have...         499  nytimes
# 499  Day 2 of the U.S. Open has started. Here's wha...         500  nytimes
#
# [500 rows x 9 columns]

# %%
sentiments_pd= sentiments_pd.set_index("User")
sentiments_pd.head()
# Out:
#       Compound                            Date  Negative  Neutral  Positive  \
# User
# BBC     0.0000  Tue Aug 28 18:56:05 +0000 2018     1.000      0.0     0.000
# BBC     0.5423  Tue Aug 28 18:03:04 +0000 2018     0.780      0.0     0.220
# BBC     0.0000  Tue Aug 28 16:01:02 +0000 2018     1.000      0.0     0.000
# BBC     0.5994  Tue Aug 28 14:51:38 +0000 2018     0.795      0.0     0.205
# BBC     0.3612  Tue Aug 28 14:51:32 +0000 2018     0.848      0.0     0.152
#
#                                          Source account  \
# User
# BBC   <a href="http://www.socialflow.com" rel="nofol...
# BBC   <a href="http://www.socialflow.com" rel="nofol...
# BBC   <a href="http://www.socialflow.com" rel="nofol...
# BBC   <a href="https://about.twitter.com/products/tw...
# BBC   <a href="https://about.twitter.com/products/tw...
#
#                                                    Text  Tweets Ago
# User
# BBC   🐢 Scientists have found new evidence confirmin...           1
# BBC   A conversation with a homeless man inspired St...           2
# BBC   😂 If Britney's songs were Scottish. https://t....           3
# BBC   RT @BBCOne: Be careful who you trust.\n\n#Body...           4
# BBC   RT @BBCiPlayer: Watch the highlights from Read...           5

# %% [markdown]
# # Save the DataFrame as a csv

# %%
sentiments_pd.to_csv("../dataoutput/media_sentiments_analysis2.csv", encoding="utf-8", index=False)

# %% [markdown]
# # Sentiment Analysis of Media Tweets

# %%
BBC_compound = sentiments_pd.loc["BBC", "Compound"]
CBS_compound = sentiments_pd.loc["CBS", "Compound"] 
CNN_compound = sentiments_pd.loc["CNN", "Compound"] 
Fox_compound = sentiments_pd.loc["FoxNews", "Compound"] 
nytimes_compound = sentiments_pd.loc["nytimes", "Compound"] 
BBC_compound =BBC_compound.reset_index()
CBS_compound =CBS_compound.reset_index()
CNN_compound =CNN_compound.reset_index()
Fox_compound =Fox_compound.reset_index()
nytimes_compound =nytimes_compound.reset_index()

# %%
Compound_df=pd.concat([BBC_compound, CBS_compound, CNN_compound, Fox_compound,nytimes_compound],axis=1)
Compound_df
Compound_df.columns.values[1] = 'BBC Compound' 
Compound_df.columns.values[3] = 'CBS Compound'
Compound_df.columns.values[5] = 'CNN Compound'
Compound_df.columns.values[7] = 'FoxNews Compound'
Compound_df.columns.values[9] = 'NYtimes Compound'
Compound_df.head()
# Out:
#   User  BBC Compound User  CBS Compound User  CNN Compound     User  \
# 0  BBC        0.0000  CBS        0.0000  CNN       -0.8957  FoxNews
# 1  BBC        0.5423  CBS       -0.4389  CNN        0.3612  FoxNews
# 2  BBC        0.0000  CBS        0.0000  CNN        0.7906  FoxNews
# 3  BBC        0.5994  CBS        0.0000  CNN       -0.8709  FoxNews
# 4  BBC        0.3612  CBS        0.5423  CNN        0.0000  FoxNews
#
#    FoxNews Compound     User  NYtimes Compound
# 0            0.0000  nytimes            0.5574
# 1            0.6369  nytimes            0.2960
# 2           -0.4019  nytimes            0.2960
# 3           -0.2006  nytimes            0.1970
# 4            0.0000  nytimes            0.0000

# %% [markdown]
# # Create plot

# %%
mpl_fig = plt.figure()
ax = mpl_fig.add_subplot(111)
ax.set_facecolor('lavender')
BBC = ax.scatter(np.arange(len(Compound_df["BBC Compound"])),
         Compound_df["BBC Compound"], marker="o", color="red", edgecolors="k",
         alpha=0.8, s=80 ) 
CBS = ax.scatter(np.arange(len(Compound_df["BBC Compound"])),
         Compound_df["CBS Compound"], marker="o", color="blue", edgecolors="k",
         alpha=0.8,s=80)
CNN = ax.scatter(np.arange(len(Compound_df["BBC Compound"])),
         Compound_df["CNN Compound"], marker="o", color="yellow", edgecolors="k",
         alpha=0.8 ,s=80)
Fox = ax.scatter(np.arange(len(Compound_df["BBC Compound"])),
         Compound_df["FoxNews Compound"], marker="o", color="green", edgecolors="k",
         alpha=0.8,s=80)
nytimes = ax.scatter(np.arange(len(Compound_df["BBC Compound"])),
         Compound_df["NYtimes Compound"], marker="o", color="black", edgecolors="k",
         alpha=0.8,s=80)
# # Incorporate the other graph properties

plt.title("Sentiment Analysis of Media Tweets (08/28/2018)")
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.grid(True, linestyle='dashed')
plt.legend((BBC, CBS, CNN, Fox, nytimes), ("BBC Compound","CBS Compound","CNN Compound","FoxNews Compound","NYtimes Compound"),
           loc='lower left',
           bbox_to_anchor=(1, 0.6))
plt.savefig("Sentiment_Analysis_of_Media_Tweets_08-28-2018")     
plt.show()

# %%
average_BBC = Compound_df["BBC Compound"].mean()
average_CBS = Compound_df["CBS Compound"].mean()
average_CNN = Compound_df["CNN Compound"].mean()
average_Fox = Compound_df["FoxNews Compound"].mean()
average_nytimes = Compound_df["NYtimes Compound"].mean()

averages = {'Compound': pd.Series([average_BBC,average_CBS,average_CNN, average_Fox, average_nytimes],index=['BBC','CBS','CNN','FoxNews','NYtimes'] )}
Compound_mean_df = pd.DataFrame(averages)
Compound_mean_df=Compound_mean_df.reset_index()
Compound_mean_df
# Out:
#      index  Compound
# 0      BBC  0.135013
# 1      CBS  0.188071
# 2      CNN -0.028137
# 3  FoxNews  0.015061
# 4  NYtimes  0.040678

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
x_axis = np.arange(0, len(Compound_mean_df["index"]))
tick_locations = []
for x in x_axis:
    tick_locations.append(x + 0.4)
ax.bar(x_axis, Compound_mean_df["Compound"], alpha=0.75, color="rbygk", align="edge")    

ax.set_ylabel('Tweet Polarity')
ax.set_title("Overrall Media Sentiment based on Twitter (08/28/2018)")
ax.set_facecolor('lavender')
plt.xticks(tick_locations, Compound_mean_df["index"])
plt.axhline(0, color='k')
plt.savefig("Overrall_Media_Sentiment_based_on_Twitter_08-28-2018")
plt.show()
